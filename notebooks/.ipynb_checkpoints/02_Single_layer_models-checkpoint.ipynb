# %% [markdown]
# # Single layer models
#
# The objective of this lab is to implement a single-layer network model consisting of solely of an affine transformation of the inputs. The relevant material for this is covered in [slides 12-23 of the first lecture](https://learn-eu-central-1-prod-fleet01-xythos.s3.eu-central-1.amazonaws.com/5d1b15b77a8ac/8300752?response-cache-control=private%2C%20max-age%3D21600&response-content-disposition=inline%3B%20filename%2A%3DUTF-8%27%27mlp01-intro.pdf&response-content-type=application%2Fpdf&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20200923T150000Z&X-Amz-SignedHeaders=host&X-Amz-Expires=21600&X-Amz-Credential=AKIAZH6WM4PL5M5HI5WH%2F20200923%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Signature=71dfeb507b5ddfeb36a8ae91927cf750a788ce97931359620586634288f70c1c).
#
# We will first implement the forward propagation of inputs to the network to produce predicted outputs. We will then move on to considering how to use gradients of an error function evaluated on the outputs to compute the gradients with respect to the model parameters to allow us to perform an iterative gradient-descent training procedure. In the final exercise you will use an interactive visualisation to explore the role of some of the different hyperparameters of gradient-descent based training methods.
#
# #### A note on random number generators
#
# It is generally a good practice (for machine learning applications **not** for cryptography!) to seed a pseudo-random number generator once at the beginning of each experiment. This makes it easier to reproduce results as the same random draws will produced each time the experiment is run (e.g. the same random initialisations used for parameters). Therefore generally when we need to generate random values during this course, we will create a seeded random number generator object as we do in the cell below.

# %%
import numpy as np
seed = 27092016 
rng = np.random.RandomState(seed)

# %% [markdown]
# ## Exercise 1: linear and affine transforms
#
# Any *linear transform* (also called a linear map) on a finite-dimensional vector space can be parametrised by a matrix. For example if we consider $\boldsymbol{x} \in \mathbb{R}^{D}$ as the input space of a model with $D$ dimensional real-valued inputs, then a matrix $\mathbf{W} \in \mathbb{R}^{K\times D}$ can be used to define a prediction model consisting solely of a linear transform of the inputs
#
# \begin{equation}
#     \boldsymbol{y} = \mathbf{W} \boldsymbol{x}
#     \qquad
#     \Leftrightarrow
#     \qquad
#     y_k = \sum_{d=1}^D \left( W_{kd} x_d \right) \quad \forall k \in \left\lbrace 1 \dots K\right\rbrace
# \end{equation}
#
# with $\boldsymbol{y} \in \mathbb{R}^K$ the $K$-dimensional real-valued output of the model. Geometrically we can think of a linear transform as some combination of rotation, scaling, reflection and shearing of the input.
#
# An *affine transform* consists of a linear transform plus an additional translation on the output space parameterised by a vector $\boldsymbol{b} \in \mathbb{R}^K$. A model consisting of an affine transformation of the inputs can then be defined as
#
# \begin{equation}
#     \boldsymbol{y} = \mathbf{W}\boldsymbol{x} + \boldsymbol{b}
#     \qquad
#     \Leftrightarrow
#     \qquad
#     y_k = \sum_{d=1}^D \left( W_{kd} x_d \right) + b_k \quad \forall k \in \left\lbrace 1 \dots K\right\rbrace
# \end{equation}
#
# In machine learning we will usually refer to the matrix $\mathbf{W}$ as a *weight matrix* and the vector $\boldsymbol{b}$ as a *bias vector*.
#
# Generally, rather than working with a single data vector $\boldsymbol{x}$ we will work with batches of datapoints $\left\lbrace \boldsymbol{x}^{(b)}\right\rbrace_{b=1}^B$. We could calculate the outputs for each input in the batch sequentially
#
# \begin{align}
#     \boldsymbol{y}^{(1)} &= \mathbf{W}\boldsymbol{x}^{(1)} + \boldsymbol{b}\\
#     \boldsymbol{y}^{(2)} &= \mathbf{W}\boldsymbol{x}^{(2)} + \boldsymbol{b}\\
#     \dots &\\
#     \boldsymbol{y}^{(B)} &= \mathbf{W}\boldsymbol{x}^{(B)} + \boldsymbol{b}\\
# \end{align}
#
# by looping over each input in the batch and calculating the output. However, loops in Python are slow (particularly compared to compiled and typed languages such as C). This is due at least in part to the large overhead in dynamically inferring variable types. In consequence, we want to avoid having loops in which this overhead would be the dominant computational cost.
#
# For array-based numerical operations, one way of overcoming this bottleneck is to *vectorise* operations, that is, computing all of them at once. NumPy `ndarrays` are typed arrays for which operations, like basic elementwise arithmetic and linear algebra operations (*e.g.*  computing matrix-matrix or matrix-vector products) are implemented by calls to highly-optimised compiled libraries. Therefore, implementing code directly using NumPy operations on arrays rather than by looping over array elements usually leads to very substantial performance gains.
#
# As a simple example, we can consider adding up two arrays `a` and `b` and writing the result to a third array `c`. Let us start by initialising `a` and `b` with arbitrary values by running the cell below.

# %%
size = 1000
a = np.arange(size)
b = np.ones(size)

# %% [markdown]
# Now, we are going to measure how long it takes to add up each pair of values in the two array and write the results to a third array using a loop-based implementation. We will use the `%%timeit` magic briefly mentioned in the previous lab notebook, specifying the number of times to loop the code as 100 and repeating it 3 times for better consistency. Run the cell below to get a print out of the average time taken.

# %%
# %%timeit -n 100 -r 3
c = np.empty(size)
for i in range(size):
    c[i] = a[i] + b[i]
# Out:
# 2.75 ms ± 117 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)

# %% [markdown]
# And now we will perform the corresponding summation with the overloaded addition operator of NumPy arrays. Again run the cell below to get a print out of the average time taken.

# %%
# %%timeit -n 100 -r 3
c = a + b
# Out:
# 3.36 µs ± 1.2 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)

# %% [markdown]
# The first loop-based implementation should have taken on the order of milliseconds ($10^{-3}$s) while the vectorised implementation should have taken on the order of microseconds ($10^{-6}$s), i.e. a $\sim1000\times$ speedup. Hopefully this simple example should make it clear why we want to vectorise operations whenever possible!
#
# Getting back to our affine model, ideally rather than individually computing the output corresponding to each input we should compute the outputs for all inputs in a batch using a vectorised implementation. As you saw last week, data providers return batches of inputs as arrays of shape `(batch_size, input_dim)`. In the mathematical notation used earlier we can consider the input as a matrix $\mathbf{X}$ of dimensionality $B \times D$:
#
# \begin{equation}
#     \mathbf{X} = \left[ \boldsymbol{x}^{(1)} ~ \boldsymbol{x}^{(2)} ~ \dots ~ \boldsymbol{x}^{(B)} \right]^\mathrm{T}
# \end{equation}
#
# i.e. the $b^{\textrm{th}}$ input vector $\boldsymbol{x}^{(b)}$ corresponds to the $b^{\textrm{th}}$ row of $\mathbf{X}$. Similarly, we can define the $B \times K$ matrix of outputs $\mathbf{Y}$ as
#
# \begin{equation}
#     \mathbf{Y} = \left[ \boldsymbol{y}^{(1)} ~ \boldsymbol{y}^{(2)} ~ \dots ~ \boldsymbol{y}^{(B)} \right]^\mathrm{T}
# \end{equation}
#
# We can then express the relationship between $\mathbf{X}$ and $\mathbf{Y}$ using [matrix multiplication](https://en.wikipedia.org/wiki/Matrix_multiplication) and addition as
#
# \begin{equation}
#     \mathbf{Y} = \mathbf{X} \mathbf{W}^\mathrm{T} + \mathbf{B}
# \end{equation}
#
# where $\mathbf{B} = \left[ \boldsymbol{b} ~ \boldsymbol{b} ~ \dots ~ \boldsymbol{b} \right]^\mathrm{T}$ i.e. a $B \times K$ matrix with each row corresponding to the same bias vector. The weight matrix needs to be transposed here as the inner dimensions of a matrix multiplication must match i.e. for $\mathbf{C} = \mathbf{A} \mathbf{B}$ then if $\mathbf{A}$ is of dimensionality $K \times L$ and $\mathbf{B}$ is of dimensionality $M \times N$ then it must be the case that $L = M$ and $\mathbf{C}$ will be of dimensionality $K \times N$.
#
# The first exercise for this lab is to implement *forward propagation* for a single-layer model consisting of an affine transformation of the inputs in the `fprop` function given as skeleton code in the cell below. This should work for a batch of inputs of shape `(batch_size, input_dim)` producing a batch of outputs of shape `(batch_size, output_dim)`.
#
# You will probably want to use the NumPy `dot` function and [broadcasting features](http://docs.scipy.org/doc/numpy/user/basics.broadcasting.html) to implement this efficiently. If you are not familiar with either of these, you may wish to read the [hints](#Hints:-Using-the-dot-function-and-broadcasting) section below which provides some tips before attempting the exercise.

# %%
def fprop(inputs, weights, biases):
    outputs=inputs.dot(weights.T)+biases
    print(outputs)
    return outputs
    raise NotImplementedError('Delete this raise statement and write your code here instead.')

# %% [markdown]
# Once you have implemented `fprop` in the cell above you can test your implementation by running the cell below.

# %%
inputs = np.array([[0., -1., 2.], [-6., 3., 1.]])
weights = np.array([[2., -3., -1.], [-5., 7., 2.]])
biases = np.array([5., -3.])
true_outputs = np.array([[6., -6.], [-17., 50.]])

if not np.allclose(fprop(inputs, weights, biases), true_outputs):
    print('Wrong outputs computed.')
else:
    print('All outputs correct!')
# Out:
# [[  6.  -6.]
#  [-17.  50.]]
# All outputs correct!

# %% [markdown]
# ### Hints: Using the `dot` function and broadcasting
#
# For those new to NumPy below are some details on the `dot` function and broadcasting feature of NumPy that you may want to use for implementing the first exercise. If you are already familiar with these and have already completed the first exercise you can move on straight to [second exercise](#Exercise-2:-visualising-random-models).
#
# #### `numpy.dot` function
#
# Matrix-matrix, matrix-vector and vector-vector (dot) products can all be computed in NumPy using the [`dot`](http://docs.scipy.org/doc/numpy/reference/generated/numpy.dot.html) operator which generalizes all of these operation. For example if `A` and `B` are both two dimensional arrays, then `C = np.dot(A, B)` or equivalently `C = A.dot(B)` will compute the matrix product of `A` and `B` assuming `A` and `B` have compatible dimensions. Similarly if `a` and `b` are one dimensional arrays then `c = np.dot(a, b)` (which is equivalent to `c = a.dot(b)`) will compute the [scalar / dot product](https://en.wikipedia.org/wiki/Dot_product) of the two arrays. If `A` is a two-dimensional array and `b` a one-dimensional array `np.dot(A, b)` (which is equivalent to `A.dot(b)`) will compute the matrix-vector product of `A` and `b`. Examples of all three of these product types are shown in the cell below:

# %%
# Initiliase arrays with arbitrary values
A = np.arange(9).reshape((3, 3))
B = np.ones((3, 3)) * 2
a = np.array([-1., 0., 1.])
b = np.array([0.1, 0.2, 0.3])
print(A.dot(B))  # Matrix-matrix product
print(B.dot(A))  # Reversed product of above. A.dot(B) != B.dot(A) in general
print(A.dot(b))  # Matrix-vector product
print(b.dot(A))  # Again A.dot(b) != b.dot(A) unless A is symmetric i.e. A == A.T
print(a.dot(b))  # Vector-vector scalar product
# Out:
# [[ 6.  6.  6.]
#  [24. 24. 24.]
#  [42. 42. 42.]]
# [[18. 24. 30.]
#  [18. 24. 30.]
#  [18. 24. 30.]]
# [0.8 2.6 4.4]
# [2.4 3.  3.6]
# 0.19999999999999998

# %% [markdown]
# #### Broadcasting
#
# Another NumPy feature it will be helpful to get familiar with is [broadcasting](http://docs.scipy.org/doc/numpy/user/basics.broadcasting.html). Broadcasting allows you to apply operations to arrays of different shapes by letting numpy infer the missing parts, for example to add a one-dimensional array to a two-dimensional array or multiply a multidimensional array by a scalar. The complete set of rules for broadcasting as explained in the official documentation page just linked to can sound a bit complex: you might find the [visual explanation on this page](http://www.scipy-lectures.org/intro/numpy/operations.html#broadcasting) more intuitive.
# Keep in mind that the shapes must be compatible with one another, and that it may lead to erroneous results if the shapes are not as intended, so you are advised to make sure your arrays have the proper shapes.
# The cell below gives a few examples:

# %%
# Initiliase arrays with arbitrary values
A = np.arange(6).reshape((3, 2))
b = np.array([0.1, 0.2])
c = np.array([-1., 0., 1.])
print(A + b)  # Add b elementwise to all rows of A
print((A.T + c).T)  # Add b elementwise to all columns of A
print(A * b)  # Multiply each row of A elementise by b
# Out:
# [[0.1 1.2]
#  [2.1 3.2]
#  [4.1 5.2]]
# [[-1.  0.]
#  [ 2.  3.]
#  [ 5.  6.]]
# [[0.  0.2]
#  [0.2 0.6]
#  [0.4 1. ]]

# %% [markdown]
# ## Exercise 2: visualising random models

# %% [markdown]
# In this exercise you will use your `fprop` implementation to visualise the outputs of a single-layer affine transform model with two-dimensional inputs and a one-dimensional output. In this simple case, we can visualise the joint input-output space on a 3D axis.
#
# For this task and the learning experiments later in the notebook we will use a regression dataset from the [UCI machine learning repository](http://archive.ics.uci.edu/ml/index.html). In particular we will use a version of the [Combined Cycle Power Plant dataset](http://archive.ics.uci.edu/ml/datasets/Combined+Cycle+Power+Plant), where the task is to predict the energy output of a power plant given observations of the local ambient conditions (e.g. temperature, pressure and humidity).
#
# The original dataset has four input dimensions and a single target output dimension. We have preprocessed the dataset by [whitening](https://en.wikipedia.org/wiki/Whitening_transformation) it. Geometrically, this process rotates the data so that it's [principle components](https://en.wikipedia.org/wiki/Principal_component_analysis) are aligned with the basis vectors, and then scales the data so that variance along each dimension is one (see [here](https://www.quora.com/What-is-the-use-of-Whitening-images-as-a-preprocessing-step-for-a-Convolutional-Neural-Network)).
#
# If the original dataset has a covariance $\mathbf{C}$, a whitening transformation $\mathbf{D}$ is one which satisfies:
# \begin{equation}
#     \mathbf{D}^{\mathrm{T}} \mathbf{C} \mathbf{D} = \mathbf{I},
# \end{equation}
# where $\mathbf{I}$ is the identity matrix.
#
# This can be considered a change of basis, where newly formed input features are decorrelated and have equivalent scale, which can lead to reduced learning times (see [here](https://proceedings.neurips.cc/paper/1990/file/758874998f5bd0c393da094e1967a72b-Paper.pdf)). We will only use the first two dimensions of the whitened inputs (corresponding to the first two principal components of the original inputs) so we can easily visualise the joint input-output space.
#
# The dataset has been wrapped in the `CCPPDataProvider` class in the `mlp.data_providers` module and the data included as a compressed file in the data directory as `ccpp_data.npz`. Running the cell below will initialise an instance of this class, get a single batch of inputs and targets, and import the necessary `matplotlib` objects.

# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('C:/Users/admin/Desktop/mlpractical')
from mpl_toolkits.mplot3d import Axes3D
from mlp.data_providers import CCPPDataProvider
# %matplotlib notebook

data_provider = CCPPDataProvider(
    which_set='train',
    input_dims=[0, 1],
    batch_size=5000, 
    max_num_batches=1, 
    shuffle_order=False
)

input_dim, output_dim = 2, 1

inputs, targets = data_provider.next()
print(inputs.shape)
print('\n\n')
print(targets.shape)
# Out:
# (5000, 2)
#
#
#
# (5000, 1)

# %% [markdown]
# Here we used the `%matplotlib notebook` magic command rather than the `%matplotlib inline` we used in the previous lab as this allows us to produce interactive 3D plots which you can rotate and zoom in/out by dragging with the mouse and scrolling the mouse-wheel respectively. Once you have finished interacting with a plot you can close it to produce a static inline plot using the <i class="fa fa-power-off"></i> button in the top-right corner.
#
# Now run the cell below to plot the predicted outputs of a randomly initialised model across the two dimensional input space as well as the true target outputs. This sort of visualisation can be a useful method (in low dimensions) to assess how well the model is likely to be able to fit the data and to judge appropriate initialisation scales for the parameters. Each time you re-run the cell a new set of random parameters will be sampled
#
# Some questions to consider:
#
#   * How do the weights and bias initialisation scale affect the sort of predicted input-output relationships?
#   * Do you think a linear model is a good choice for this data?

# %%
weights_init_range = 0.5
biases_init_range = 0.1

# Randomly initialise weights matrix
weights = rng.uniform(
    low=-weights_init_range, 
    high=weights_init_range, 
    size=(output_dim, input_dim)
)

#  Randomly initialise biases vector
biases = rng.uniform(
    low=-biases_init_range, 
    high=biases_init_range, 
    size=output_dim
)
# Calculate predicted model outputs
outputs = fprop(inputs, weights, biases)

# Plot target and predicted outputs against inputs on same axis
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot(inputs[:, 0], inputs[:, 1], targets[:, 0], 'r.', ms=2)
ax.plot(inputs[:, 0], inputs[:, 1], outputs[:, 0], 'b.', ms=2)
ax.set_xlabel('Input dim 1')
ax.set_ylabel('Input dim 2')
ax.set_zlabel('Output')
ax.legend(['Targets', 'Predictions'], frameon=False)
fig.tight_layout()
# Out:
# [[ 0.28534701]
#  [ 0.21926016]
#  [ 0.2506353 ]
#  ...
#  [ 0.14474414]
#  [-0.02417224]
#  [-0.01229144]]
# <img src="data:image/png;base64,..." width="800.0000211927631">

# %% [markdown]
# ## Exercise 3: computing the error function and its gradient
#
# We will now consider the task of regression as covered in the first lecture. Given a set of inputs $\left\lbrace \boldsymbol{x}^{(n)}\right\rbrace_{n=1}^N$, the aim in a regression problem is to produce outputs $\left\lbrace \boldsymbol{y}^{(n)}\right\rbrace_{n=1}^N$ that are as 'close' as possible to a set of targets $\left\lbrace \boldsymbol{t}^{(n)}\right\rbrace_{n=1}^N$. The measure of 'closeness' or distance between target and predicted outputs can vary and is usually a design choice.
#
# A very common choice is the squared Euclidean distance between the predicted and target outputs. This can be computed as the sum of the squared differences between each element in the target and predicted outputs. A widespread convention is to multiply this value by $\frac{1}{2}$ as this gives a slightly nicer expression for the error gradient. The error for the $n^{\textrm{th}}$ training example is then expresed by
#
# \begin{equation}
#     E^{(n)} = \frac{1}{2} \sum_{k=1}^K \left\lbrace \left( y^{(n)}_k - t^{(n)}_k \right)^2 \right\rbrace.
# \end{equation}
#
# The overall error is defined as the *average* of this value across all training examples
#
# \begin{equation}
#     \bar{E} = \frac{1}{N} \sum_{n=1}^N \left\lbrace E^{(n)} \right\rbrace.
# \end{equation}
#
# *Note here we are using a slightly different convention from the lectures. There the overall error was considered to be the sum of the individual error terms rather than the mean. To differentiate between the two we will use $\bar{E}$ to represent the average error here as opposed to sum of errors $E$ as used in the slides with $\bar{E} = \frac{E}{N}$. Normalising by the number of training examples is helpful to do in practice as this means we can more easily compare errors across data sets / batches of different sizes, and more importantly it means the size of our gradient updates will be independent of the number of training examples summed over.*
#
# Solving the regression problem means finding parameters of the model which minimise $\bar{E}$. For our simple single-layer affine model here, that corresponds to finding weights $\mathbf{W}$ and biases $\boldsymbol{b}$ which minimise $\bar{E}$.
#
# As mentioned in the lecture, in this case there is actually a closed form solution for the optimal weights and bias parameters. This is the linear least-squares solution those doing MLPR will have come across.
#
# However in general we will be interested in models where closed form solutions do not exist. Tjerefore, we will generally use iterative gradient descent based optimization methods to find parameters which (locally) minimise the error function. A basic requirement of being able to do gradient-descent based training is (unsuprisingly) the ability to evaluate gradients of the error function.
#
# Our end goal is to calculate gradients of the error function with respect to the model parameters $\mathbf{W}$ and $\boldsymbol{b}$. As a first step here we will consider the gradient of the error function with respect to the model outputs $\left\lbrace \boldsymbol{y}^{(n)}\right\rbrace_{n=1}^N$. This can be written
#
# \begin{equation}
#     \frac{\partial \bar{E}}{\partial \boldsymbol{y}^{(n)}} = \frac{1}{N} \left( \boldsymbol{y}^{(n)} - \boldsymbol{t}^{(n)} \right)
#     \qquad \Leftrightarrow \qquad
#     \frac{\partial \bar{E}}{\partial y^{(n)}_k} = \frac{1}{N} \left( y^{(n)}_k - t^{(n)}_k \right) \quad \forall k \in \left\lbrace 1 \dots K\right\rbrace
# \end{equation}
#
# *i.e.* the gradient of the error function with respect to the $n^{\textrm{th}}$ model output is the difference between the $n^{\textrm{th}}$ model and target outputs, corresponding to the $\boldsymbol{\delta}^{(n)}$ terms mentioned in the lecture slides.
#
# Using the equations given above, implement functions computing the mean sum of squared differences error and its gradient with respect to the model outputs. You should implement the functions using the provided skeleton definitions in the cell below.

# %%
def error(outputs, targets):
    E=(((outputs-targets)**2).sum())*(1/(2*outputs.shape[0]))
    return E
    
def error_grad(outputs, targets):
    grad=(1/outputs.shape[0])*(outputs-targets)
    return grad

# %% [markdown]
# Check your implementation by running the test cell below.

# %%
outputs = np.array([[1., 2.], [-1., 0.], [6., -5.], [-1., 1.]])
targets = np.array([[0., 1.], [3., -2.], [7., -3.], [1., -2.]])
true_error = 5.
true_error_grad = np.array([[0.25, 0.25], [-1., 0.5], [-0.25, -0.5], [-0.5, 0.75]])
if not error(outputs, targets) == true_error:
    print('Error calculated incorrectly.')
elif not np.allclose(error_grad(outputs, targets), true_error_grad):
    print('Error gradient calculated incorrectly.')
else:
    print('Error function and gradient computed correctly!')
# Out:
# Error function and gradient computed correctly!

# %% [markdown]
# ## Exercise 4: computing gradients with respect to the parameters
#
# In the previous exercise you implemented a function computing the gradient of the error function with respect to the model outputs. For gradient-descent based training, we need to be able to evaluate the gradient of the error function with respect to the model parameters.
#
# Using the [chain rule for derivatives](https://en.wikipedia.org/wiki/Chain_rule#Higher_dimensions), we can write the partial deriviative of the error function with respect to single elements of the weight matrix and bias vector as
#
# \begin{equation}
#     \frac{\partial E}{\partial W_{kj}} = \sum_{n=1}^N \left\lbrace \frac{\partial E}{\partial y^{(n)}_k} \frac{\partial y^{(n)}_k}{\partial W_{kj}} \right\rbrace
#     \quad \textrm{and} \quad
#     \frac{\partial E}{\partial b_k} = \sum_{n=1}^N \left\lbrace \frac{\partial E}{\partial y^{(n)}_k} \frac{\partial y^{(n)}_k}{\partial b_k} \right\rbrace.
# \end{equation}
#
# From the definition of our model at the beginning we have
#
# \begin{equation}
#     y^{(n)}_k = \sum_{d=1}^D \left\lbrace W_{kd} x^{(n)}_d \right\rbrace + b_k
#     \quad \Rightarrow \quad
#     \frac{\partial y^{(n)}_k}{\partial W_{kj}} = x^{(n)}_j
#     \quad \textrm{and} \quad
#     \frac{\partial y^{(n)}_k}{\partial b_k} = 1.
# \end{equation}
#
# Putting this together we get that
#
# \begin{equation}
#     \frac{\partial E}{\partial W_{kj}} =
#     \sum_{n=1}^N \left\lbrace \frac{\partial E}{\partial y^{(n)}_k} x^{(n)}_j \right\rbrace
#     \quad \textrm{and} \quad
#     \frac{\partial E}{\partial b_{k}} =
#     \sum_{n=1}^N \left\lbrace \frac{\partial E}{\partial y^{(n)}_k} \right\rbrace.
# \end{equation}
#
# Although this may seem a bit of a roundabout way to get to these results, this method of decomposing the error gradient with respect to the parameters in terms of the gradient of the error function with respect to the model outputs and the derivatives of the model outputs with respect to the model parameters is the key element that allows calculating the parameter gradients of more complex models we will study later in the course.
#
# Your task in this exercise is to implement a function calculating the gradient of the error function with respect to the weight and bias parameters of the model given the already computed gradient of the error function with respect to the model outputs. You should implement this in the `grads_wrt_params` function in the cell below.

# %%
def grads_wrt_params(inputs, grads_wrt_outputs):
    
    grads_wrt_weights=(inputs.T.dot(grads_wrt_outputs)).T
    grads_wrt_biases=np.ones((1,inputs.shape[0])).dot(grads_wrt_outputs)
    return [grads_wrt_weights,grads_wrt_biases]

# %% [markdown]
# Check your implementation by running the test cell below.

# %%
inputs = np.array([[1., 2., 3.], [-1., 4., -9.]])
grads_wrt_outputs = np.array([[-1., 1.], [2., -3.]])
true_grads_wrt_weights = np.array([[-3., 6., -21.], [4., -10., 30.]])
true_grads_wrt_biases = np.array([1., -2.])

grads_wrt_weights, grads_wrt_biases = grads_wrt_params(
    inputs, grads_wrt_outputs)

if not np.allclose(true_grads_wrt_weights, grads_wrt_weights):
    print('Gradients with respect to weights incorrect.')
elif not np.allclose(true_grads_wrt_biases, grads_wrt_biases):
    print('Gradients with respect to biases incorrect.')
else:
    print('All parameter gradients calculated correctly!')
# Out:
# All parameter gradients calculated correctly!

# %% [markdown]
# ## Exercise 5: wrapping the functions into reusable components
#
# In exercises 1, 3 and 4 you implemented methods to compute the predicted outputs of our model, evaluate the error function and its gradient on the outputs and finally to calculate the gradients of the error with respect to the model parameters. Together they constitute all the basic ingredients we need to implement a gradient-descent based iterative learning procedure.
#
# Although you could implement training code which directly uses the functions you defined, this would only be usable for this particular model architecture. In subsequent labs we will want to use the affine transform functions as the basis for more interesting multi-layer models. We will therefore wrap the implementations you just wrote in to reusable components that we can combine to build more complex models later in the course.
#
#   * In the [`mlp.layers`](/edit/mlp/layers.py) module, use your implementations of `fprop` and `grad_wrt_params` above to implement the corresponding methods in the skeleton `AffineLayer` class provided.
#   * In the [`mlp.errors`](/edit/mlp/errors.py) module use your implementation of `error` and `error_grad` to implement the `__call__` and `grad` methods respectively of the skeleton `SumOfSquaredDiffsError` class provided. Note `__call__` is a special Python method that allows an object to be used with a function call syntax.
#
# Run the cell below to use your completed `AffineLayer` and `SumOfSquaredDiffsError` implementations to train a single-layer model using batch gradient descent on the CCPP dataset.

# %%
from mlp.layers import AffineLayer
from mlp.errors import SumOfSquaredDiffsError
from mlp.models import SingleLayerModel
from mlp.initialisers import UniformInit, ConstantInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser
import logging

# Seed a random number generator
seed = 27092016 
rng = np.random.RandomState(seed)

# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the CCPP training set
train_data = CCPPDataProvider('train', [0, 1], batch_size=100, rng=rng)
input_dim, output_dim = 2, 1


# Create a parameter initialiser which will sample random uniform values
# from [-0.1, 0.1]
param_init = UniformInit(-0.1, 0.1, rng=rng)

# Create our single layer model
layer = AffineLayer(input_dim, output_dim, param_init, param_init)
model = SingleLayerModel(layer)
# Initialise the error object
error = SumOfSquaredDiffsError()

# Use a basic gradient descent learning rule with a small learning rate
learning_rule = GradientDescentLearningRule(learning_rate=1e-2)

# Use the created objects to initialise a new Optimiser instance.
optimiser = Optimiser(model, error, learning_rule, train_data)

# Run the optimiser for 5 epochs (full passes through the training set)
# printing statistics every epoch.
stats, keys = optimiser.train(num_epochs=10, stats_interval=1)

# Plot the change in the error over training.
fig = plt.figure(figsize=(8, 4))
ax = fig.add_subplot(111)
ax.plot(np.arange(1, stats.shape[0] + 1), stats[:, keys['error(train)']])
ax.set_xlabel('Epoch number')
ax.set_ylabel('Error')
# Out:
# Epoch 1: 0.0s to complete
#     error(train)=1.67e-01
# Epoch 2: 0.0s to complete
#     error(train)=9.30e-02
# Epoch 3: 0.0s to complete
#     error(train)=7.95e-02
# Epoch 4: 0.0s to complete
#     error(train)=7.71e-02
# Epoch 5: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 6: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 7: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 8: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 9: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 10: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 11: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 12: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 13: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 14: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 15: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 16: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 17: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 18: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 19: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 20: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 21: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 22: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 23: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 24: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 25: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 26: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 27: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 28: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 29: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 30: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 31: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 32: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 33: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 34: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 35: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 36: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 37: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 38: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 39: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 40: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 41: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 42: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 43: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 44: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 45: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 46: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 47: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 48: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 49: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 50: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 51: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 52: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 53: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 54: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 55: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 56: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 57: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 58: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 59: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 60: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 61: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 62: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 63: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 64: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 65: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 66: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 67: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 68: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 69: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 70: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 71: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 72: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 73: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 74: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 75: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 76: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 77: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 78: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 79: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 80: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 81: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 82: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 83: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 84: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 85: 0.0s to complete
#     error(train)=7.60e-02
# Epoch 86: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 87: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 88: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 89: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 90: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 91: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 92: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 93: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 94: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 95: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 96: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 97: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 98: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 99: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 100: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 101: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 102: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 103: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 104: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 105: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 106: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 107: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 108: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 109: 0.0s to complete
#     error(train)=7.61e-02
# Epoch 110: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 111: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 112: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 113: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 114: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 115: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 116: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 117: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 118: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 119: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 120: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 121: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 122: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 123: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 124: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 125: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 126: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 127: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 128: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 129: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 130: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 131: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 132: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 133: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 134: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 135: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 136: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 137: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 138: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 139: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 140: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 141: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 142: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 143: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 144: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 145: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 146: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 147: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 148: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 149: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 150: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 151: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 152: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 153: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 154: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 155: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 156: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 157: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 158: 0.0s to complete
#     error(train)=7.61e-02
# Epoch 159: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 160: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 161: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 162: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 163: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 164: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 165: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 166: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 167: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 168: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 169: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 170: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 171: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 172: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 173: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 174: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 175: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 176: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 177: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 178: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 179: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 180: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 181: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 182: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 183: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 184: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 185: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 186: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 187: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 188: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 189: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 190: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 191: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 192: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 193: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 194: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 195: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 196: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 197: 0.0s to complete
#     error(train)=7.61e-02
# Epoch 198: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 199: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 200: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 201: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 202: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 203: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 204: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 205: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 206: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 207: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 208: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 209: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 210: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 211: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 212: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 213: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 214: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 215: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 216: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 217: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 218: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 219: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 220: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 221: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 222: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 223: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 224: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 225: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 226: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 227: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 228: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 229: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 230: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 231: 0.0s to complete
#     error(train)=7.61e-02
# Epoch 232: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 233: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 234: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 235: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 236: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 237: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 238: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 239: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 240: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 241: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 242: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 243: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 244: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 245: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 246: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 247: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 248: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 249: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 250: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 251: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 252: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 253: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 254: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 255: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 256: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 257: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 258: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 259: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 260: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 261: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 262: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 263: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 264: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 265: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 266: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 267: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 268: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 269: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 270: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 271: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 272: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 273: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 274: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 275: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 276: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 277: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 278: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 279: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 280: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 281: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 282: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 283: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 284: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 285: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 286: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 287: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 288: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 289: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 290: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 291: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 292: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 293: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 294: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 295: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 296: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 297: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 298: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 299: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 300: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 301: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 302: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 303: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 304: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 305: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 306: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 307: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 308: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 309: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 310: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 311: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 312: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 313: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 314: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 315: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 316: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 317: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 318: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 319: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 320: 0.0s to complete
#     error(train)=7.68e-02
# Epoch 321: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 322: 0.0s to complete
#     error(train)=7.61e-02
# Epoch 323: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 324: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 325: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 326: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 327: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 328: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 329: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 330: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 331: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 332: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 333: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 334: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 335: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 336: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 337: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 338: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 339: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 340: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 341: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 342: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 343: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 344: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 345: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 346: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 347: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 348: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 349: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 350: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 351: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 352: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 353: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 354: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 355: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 356: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 357: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 358: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 359: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 360: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 361: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 362: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 363: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 364: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 365: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 366: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 367: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 368: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 369: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 370: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 371: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 372: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 373: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 374: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 375: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 376: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 377: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 378: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 379: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 380: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 381: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 382: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 383: 0.0s to complete
#     error(train)=7.60e-02
# Epoch 384: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 385: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 386: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 387: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 388: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 389: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 390: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 391: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 392: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 393: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 394: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 395: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 396: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 397: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 398: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 399: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 400: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 401: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 402: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 403: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 404: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 405: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 406: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 407: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 408: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 409: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 410: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 411: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 412: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 413: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 414: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 415: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 416: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 417: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 418: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 419: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 420: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 421: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 422: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 423: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 424: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 425: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 426: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 427: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 428: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 429: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 430: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 431: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 432: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 433: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 434: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 435: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 436: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 437: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 438: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 439: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 440: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 441: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 442: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 443: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 444: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 445: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 446: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 447: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 448: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 449: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 450: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 451: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 452: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 453: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 454: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 455: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 456: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 457: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 458: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 459: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 460: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 461: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 462: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 463: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 464: 0.0s to complete
#     error(train)=7.61e-02
# Epoch 465: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 466: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 467: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 468: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 469: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 470: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 471: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 472: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 473: 0.0s to complete
#     error(train)=7.58e-02
# Epoch 474: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 475: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 476: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 477: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 478: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 479: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 480: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 481: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 482: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 483: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 484: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 485: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 486: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 487: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 488: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 489: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 490: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 491: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 492: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 493: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 494: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 495: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 496: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 497: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 498: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 499: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 500: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 501: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 502: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 503: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 504: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 505: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 506: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 507: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 508: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 509: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 510: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 511: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 512: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 513: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 514: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 515: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 516: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 517: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 518: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 519: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 520: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 521: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 522: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 523: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 524: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 525: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 526: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 527: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 528: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 529: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 530: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 531: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 532: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 533: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 534: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 535: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 536: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 537: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 538: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 539: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 540: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 541: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 542: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 543: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 544: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 545: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 546: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 547: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 548: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 549: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 550: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 551: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 552: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 553: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 554: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 555: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 556: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 557: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 558: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 559: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 560: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 561: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 562: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 563: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 564: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 565: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 566: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 567: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 568: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 569: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 570: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 571: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 572: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 573: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 574: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 575: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 576: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 577: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 578: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 579: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 580: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 581: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 582: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 583: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 584: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 585: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 586: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 587: 0.0s to complete
#     error(train)=7.68e-02
# Epoch 588: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 589: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 590: 0.0s to complete
#     error(train)=7.68e-02
# Epoch 591: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 592: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 593: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 594: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 595: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 596: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 597: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 598: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 599: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 600: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 601: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 602: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 603: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 604: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 605: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 606: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 607: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 608: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 609: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 610: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 611: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 612: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 613: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 614: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 615: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 616: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 617: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 618: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 619: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 620: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 621: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 622: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 623: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 624: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 625: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 626: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 627: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 628: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 629: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 630: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 631: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 632: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 633: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 634: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 635: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 636: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 637: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 638: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 639: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 640: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 641: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 642: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 643: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 644: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 645: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 646: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 647: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 648: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 649: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 650: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 651: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 652: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 653: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 654: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 655: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 656: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 657: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 658: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 659: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 660: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 661: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 662: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 663: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 664: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 665: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 666: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 667: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 668: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 669: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 670: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 671: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 672: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 673: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 674: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 675: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 676: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 677: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 678: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 679: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 680: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 681: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 682: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 683: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 684: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 685: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 686: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 687: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 688: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 689: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 690: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 691: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 692: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 693: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 694: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 695: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 696: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 697: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 698: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 699: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 700: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 701: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 702: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 703: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 704: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 705: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 706: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 707: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 708: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 709: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 710: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 711: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 712: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 713: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 714: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 715: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 716: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 717: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 718: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 719: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 720: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 721: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 722: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 723: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 724: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 725: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 726: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 727: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 728: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 729: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 730: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 731: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 732: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 733: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 734: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 735: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 736: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 737: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 738: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 739: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 740: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 741: 0.0s to complete
#     error(train)=7.60e-02
# Epoch 742: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 743: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 744: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 745: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 746: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 747: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 748: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 749: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 750: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 751: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 752: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 753: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 754: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 755: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 756: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 757: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 758: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 759: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 760: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 761: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 762: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 763: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 764: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 765: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 766: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 767: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 768: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 769: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 770: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 771: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 772: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 773: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 774: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 775: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 776: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 777: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 778: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 779: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 780: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 781: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 782: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 783: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 784: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 785: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 786: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 787: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 788: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 789: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 790: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 791: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 792: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 793: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 794: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 795: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 796: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 797: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 798: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 799: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 800: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 801: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 802: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 803: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 804: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 805: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 806: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 807: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 808: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 809: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 810: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 811: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 812: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 813: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 814: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 815: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 816: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 817: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 818: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 819: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 820: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 821: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 822: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 823: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 824: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 825: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 826: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 827: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 828: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 829: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 830: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 831: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 832: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 833: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 834: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 835: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 836: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 837: 0.0s to complete
#     error(train)=7.61e-02
# Epoch 838: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 839: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 840: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 841: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 842: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 843: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 844: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 845: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 846: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 847: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 848: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 849: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 850: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 851: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 852: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 853: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 854: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 855: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 856: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 857: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 858: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 859: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 860: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 861: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 862: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 863: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 864: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 865: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 866: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 867: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 868: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 869: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 870: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 871: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 872: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 873: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 874: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 875: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 876: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 877: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 878: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 879: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 880: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 881: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 882: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 883: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 884: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 885: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 886: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 887: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 888: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 889: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 890: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 891: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 892: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 893: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 894: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 895: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 896: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 897: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 898: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 899: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 900: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 901: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 902: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 903: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 904: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 905: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 906: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 907: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 908: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 909: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 910: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 911: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 912: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 913: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 914: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 915: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 916: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 917: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 918: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 919: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 920: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 921: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 922: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 923: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 924: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 925: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 926: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 927: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 928: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 929: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 930: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 931: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 932: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 933: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 934: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 935: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 936: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 937: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 938: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 939: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 940: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 941: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 942: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 943: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 944: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 945: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 946: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 947: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 948: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 949: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 950: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 951: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 952: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 953: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 954: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 955: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 956: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 957: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 958: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 959: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 960: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 961: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 962: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 963: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 964: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 965: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 966: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 967: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 968: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 969: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 970: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 971: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 972: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 973: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 974: 0.0s to complete
#     error(train)=7.62e-02
# Epoch 975: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 976: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 977: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 978: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 979: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 980: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 981: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 982: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 983: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 984: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 985: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 986: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 987: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 988: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 989: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 990: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 991: 0.0s to complete
#     error(train)=7.64e-02
# Epoch 992: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 993: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 994: 0.0s to complete
#     error(train)=7.65e-02
# Epoch 995: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 996: 0.0s to complete
#     error(train)=7.63e-02
# Epoch 997: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 998: 0.0s to complete
#     error(train)=7.67e-02
# Epoch 999: 0.0s to complete
#     error(train)=7.66e-02
# Epoch 1000: 0.0s to complete
#     error(train)=7.64e-02

# %% [markdown]
# Using similar code to exercise 2, we can visualise the joint input-output space for the trained model. If you implemented the required methods correctly you should now see a much improved fit between predicted and target outputs when running the cell below.

# %%
data_provider = CCPPDataProvider(
    which_set='train',
    input_dims=[0, 1],
    batch_size=5000, 
    max_num_batches=1, 
    shuffle_order=False
)

inputs, targets = data_provider.next()

# Calculate predicted model outputs
outputs = model.fprop(inputs)[-1]

# Plot target and predicted outputs against inputs on same axis
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot(inputs[:, 0], inputs[:, 1], targets[:, 0], 'r.', ms=2)
ax.plot(inputs[:, 0], inputs[:, 1], outputs[:, 0], 'b.', ms=2)
ax.set_xlabel('Input dim 1')
ax.set_ylabel('Input dim 2')
ax.set_zlabel('Output')
ax.legend(['Targets', 'Predictions'], frameon=False)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800.0000211927631">

# %% [markdown]
# ## Exercise 6: visualising training trajectories in parameter space

# %% [markdown]
# Running the cell below will display an interactive widget which plots the trajectories of gradient-based training of the single-layer affine model on the CCPP dataset in the three dimensional parameter space (two weights plus bias) from random initialisations. Also shown on the right is a plot of the evolution of the error function (evaluated on the current batch) over training. By moving the sliders you can alter the training hyperparameters to investigate the effect they have on how training procedes. The hyperparameters are as follows:
#
# - `n_epochs` : number of training epochs,
# - `batch_size` : number of data points per batch,
# - `log_lr` : logarithm of the learning rate,
# - `n_inits` : number of different parameter initializations,
# - `w_scale` : min/max initial weight value,
# - `b_scale` : min/max initial bias value,
# - `elev`/`azim` : spherical coordinates for camera position.
#
# When adjusting these hyperparameters, keep in mind that the magnitude of each (per batch) update is independent of the batch size. Increasing the batch size may there for necessitate a larger number of epochs to ensure convergence, or a larger learning rate.
#
# Some questions to explore:
#
#   * Are there multiple local minima in parameter space here? Why?
#   * What are the effects of using very small learning rates? And very large learning ones?
#   * How does the batch size affect learning?
#
# **Note:** You don't need to understand how the code below works. The idea of this exercise is to help you understand the role of the various hyperparameters involved in gradient-descent based training methods.

# %%
from ipywidgets import interact
# %matplotlib inline

def setup_figure():
    # create figure and axes
    fig = plt.figure(figsize=(12, 6))
    ax1 = fig.add_axes([0., 0., 0.5, 1.], projection='3d')
    ax2 = fig.add_axes([0.6, 0.1, 0.4, 0.8])
    # set axes properties
    ax2.spines['right'].set_visible(False)
    ax2.spines['top'].set_visible(False)
    ax2.yaxis.set_ticks_position('left')
    ax2.xaxis.set_ticks_position('bottom')
    ax2.set_yscale('log')
    ax1.set_xlim((-2, 2))
    ax1.set_ylim((-2, 2))
    ax1.set_zlim((-2, 2))
    #set axes labels and title
    ax1.set_title('Parameter trajectories over training')
    ax1.set_xlabel('Weight 1')
    ax1.set_ylabel('Weight 2')
    ax1.set_zlabel('Bias')
    ax2.set_title('Batch errors over training')
    ax2.set_xlabel('Batch update number')
    ax2.set_ylabel('Batch error')
    return fig, ax1, ax2

def visualise_training(n_epochs=1, batch_size=200, log_lr=-1., n_inits=5,
                       w_scale=1., b_scale=1., elev=30., azim=0.):
    fig, ax1, ax2 = setup_figure()
    # create seeded random number generator
    rng = np.random.RandomState(1234)
    # create data provider
    data_provider = CCPPDataProvider(
        input_dims=[0, 1],
        batch_size=batch_size, 
        shuffle_order=False,
    )
    learning_rate = 10 ** log_lr
    n_batches = data_provider.num_batches
    weights_traj = np.empty((n_inits, n_epochs * n_batches + 1, 1, 2))
    biases_traj = np.empty((n_inits, n_epochs * n_batches + 1, 1))
    errors_traj = np.empty((n_inits, n_epochs * n_batches))
    # randomly initialise parameters
    weights = rng.uniform(-w_scale, w_scale, (n_inits, 1, 2))
    biases = rng.uniform(-b_scale, b_scale, (n_inits, 1))
    # store initial parameters
    weights_traj[:, 0] = weights
    biases_traj[:, 0] = biases
    # iterate across different initialisations
    for i in range(n_inits):
        # iterate across epochs
        for e in range(n_epochs):
            # iterate across batches
            for b, (inputs, targets) in enumerate(data_provider):
                outputs = fprop(inputs, weights[i], biases[i])
                errors_traj[i, e * n_batches + b] = error(outputs, targets)
                grad_wrt_outputs = error_grad(outputs, targets)
                weights_grad, biases_grad = grads_wrt_params(inputs, grad_wrt_outputs)
                weights[i] -= learning_rate * weights_grad
                biases[i] -= learning_rate * biases_grad
                weights_traj[i, e * n_batches + b + 1] = weights[i]
                biases_traj[i, e * n_batches + b + 1] = biases[i]
    # choose a different color for each trajectory
    colors = plt.cm.jet(np.linspace(0, 1, n_inits))
    # plot all trajectories
    for i in range(n_inits):
        lines_1 = ax1.plot(
            weights_traj[i, :, 0, 0], 
            weights_traj[i, :, 0, 1], 
            biases_traj[i, :, 0], 
            '-', c=colors[i], lw=2)
        lines_2 = ax2.plot(
            np.arange(n_batches * n_epochs),
            errors_traj[i],
            c=colors[i]
        )
    ax1.view_init(elev, azim)
    plt.show()

w = interact(
    visualise_training,
    elev=(-90, 90, 2),
    azim=(-180, 180, 2), 
    n_epochs=(1, 5), 
    batch_size=(100, 1000, 100),
    log_lr=(-3., 1.),
    w_scale=(0., 2.),
    b_scale=(0., 2.),
    n_inits=(1, 10)
)

for child in w.widget.children:
    child.layout.width = '100%'
# Out:
# interactive(children=(IntSlider(value=1, description='n_epochs', max=5, min=1), IntSlider(value=200, descripti…

# %% [markdown]
# # Hints:
# - Remember an affine single layer model is an linear with respect to it's parameters, such that any given output $y$ can be expressed as $y = w_1 x_1 + w_2 x_2 + b$. Subsituting this into the loss function we have:
# \begin{equation}
#     E =  \sum_{n=1}^K \frac{1}{2}  \left( y^{(n)} - t^{(n)} \right)^2 = \sum_{n=1}^K \frac{1}{2}  \left( w_1 x_1^{(n)} + w_2 x_2^{(n)} + b - t^{(n)} \right)^2.
# \end{equation}
# The loss surface is therefore *quadratic* with respect to parameters $w_1, w_2, b$. What effect does this have on the number of minima?
#
# - Note that by using batch-wise updates, we are computing gradients of loss surface described by a subset $B < N$ of the training data:
# \begin{equation}
#     E =  \sum_{n=1}^B \frac{1}{2}  \left( y^{(n)} - t^{(n)} \right)^2.
# \end{equation}
# Hence, this gradient direction is only an approximation of the optimal update direction dictated by the full dataset. With very small batch sizes, what convergence behaviour would we therefore expect?
